# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %matplotlib widget

# %% [markdown]
# # Generate Data

# %%
jumlah_data = 100

y = np.array([i*0.1+np.random.randn() for i in range (jumlah_data)])
x = np.array([i*0.1 for i in range(jumlah_data)])

# %% [markdown]
# ### Plot data

# %%
plt.scatter(x,y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### fungsi linear

# %%
def linear(x, gradien):
    y = gradien*x
    return y

# %% [markdown]
# ### menghitung persamaan awal

# %%
x_predic = np.array ([0,10])
m_awal = 5
y_predic = linear(x_predic,m_awal)

# %%
# plt.scatter(x,y)
#plt.plot(x_predic,y_predic, "Red")
#plt.axis([0,10,0,10])
#plt.show
y_predic = linear(x[i],m_predic)
plt.show(y_predic)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### menghitung prediksi

# %%
m_predic = m_awal
m_list_predic = []
y_list_predic = []
x_list_predic = []
learning_rate = 0.1

for i in range(1,jumlah_data):
    y_predic = linear(x[i],m_predic)
    y_actual = y[i]

    error = y_actual - y_predic
    delta_m = learning_rate * error/x[i]
    m_predic = m_predic + delta_m

    m_list_predic.append(m_predic)
    y_list_predic.append(y_predic)
    x_list_predic.append(x[i])

# %% [markdown]
# ### visualisasi

# %%
fig = plt.figure()
line, = plt.plot([],[],"red")

def animate(frame_num):
    x = [0, x_list_predic[frame_num]]
    y = [0, y_list_predic[frame_num]]
    line.set_data((x,y))
    return line

plt.scatter(x,y)
plt.axis([0,10,0,10])

anime = FuncAnimation(fig,animate,frames=100,interval=100,repeat=False)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
